# %%
from sklearn.datasets import fetch_20newsgroups
import pandas as pd


newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))

    df = pd.DataFrame([newsgroups_train.data, newsgroups_train.target.tolist()]).T
    df.columns = ['text', 'target']

    targets = pd.DataFrame( newsgroups_train.target_names)
    targets.columns=['title']

    out = pd.merge(df, targets, left_on='target', right_index=True)
    out['date'] = pd.to_datetime('now')
    out.to_csv('20_newsgroup.csv')
    
twenty_newsgroup_to_csv()
# Out:
# Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)

# %%
newsgroups_test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'))

# %%
df = pd.DataFrame([newsgroups_test.data, newsgroups_test.target.tolist()]).T
df.columns = ['text', 'target']
df["text"] = df["text"].replace("\n|\t"," ", regex=True)
targets = pd.DataFrame( newsgroups_train.target_names)
targets.columns=['title']
out = pd.merge(df, targets, left_on='target', right_index=True)
out.to_csv('20_newsgroup_test.csv')
data = pd.read_csv('20_newsgroup_test.csv') 
data
# Out:
#       Unnamed: 0                                               text  target  \
# 0              0  I am a little confused on all of the models of...       7
# 1             27  I have a 90 Eagle Talon and I wanted a pair of...       7
# 2             28  Hi, I need your help with a problem I have wit...       7
# 3             75   They changed the lights and slope of the hood...       7
# 4             77  I am thinking of buying a used Audi 90 Auto.  ...       7
# ...          ...                                                ...     ...
# 7527        7426   I think it's because the lead gets coated wit...      12
# 7528        7445     With regards to what you wrote, how does on...      12
# 7529        7507   Why can't he record it legally?  It may not b...      12
# 7530        7510     It sorta depends on what you drive. I remem...      12
# 7531        7519  Can anyone point me to a cross compiler and/or...      12
#
#                 title
# 0           rec.autos
# 1           rec.autos
# 2           rec.autos
# 3           rec.autos
# 4           rec.autos
# ...               ...
# 7527  sci.electronics
# 7528  sci.electronics
# 7529  sci.electronics
# 7530  sci.electronics
# 7531  sci.electronics
#
# [7532 rows x 4 columns]

# %%
newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
