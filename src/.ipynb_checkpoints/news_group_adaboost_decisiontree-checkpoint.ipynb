# %%
import model as m
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
#stop word sets specified for this data set
path = "../data/stop_words_news_groups/"
with open(path+"stop_words_no_numbers.txt", 'r') as content_file:
        content = content_file.read().replace(" ","").replace("\n","").split(",")
        stop_words_no_nums = frozenset(content)
with open(path+"stop_words_with_nums.txt", 'r') as content_file:
        content = content_file.read().replace(" ","").replace("\n","").split(",")
        stop_words_with_nums = frozenset(content)

# %%
clf_1 = m.Classifier(1,AdaBoostClassifier())

params_trial_1 = {
    'vect__max_features': [(12000)],
    'vect__ngram_range': [(1, 1)],
    'tfidf__norm': [('l2')],
    'vect__stop_words' : [stop_words_no_nums],
    'clf__base_estimator': [DecisionTreeClassifier(criterion='gini',max_depth=1000,min_samples_leaf=1,min_samples_split=0.001,splitter='random',ccp_alpha=0.0001)],
    'clf__n_estimators': [10,20],
    'clf__learning_rate': (0.8,1),
}

clf_1.fit(params_trial_1,5)
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  20 | elapsed:  4.5min remaining:  4.5min
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed: 12.7min remaining:  4.2min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 18.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 18.3min finished
# done in 1348.777s
#
# scores!
# mean: 0.488 std: (+/-0.028) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.482 std: (+/-0.010) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.490 std: (+/-0.019) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.490 std: (+/-0.020) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# Best score:
# 0.490 (+/-0.020)
# with parameters set:
# 	clf__base_estimator: DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')
# 	clf__learning_rate: 1
# 	clf__n_estimators: 20
# 	tfidf__norm: 'l2'
# 	vect__max_features: 12000
# 	vect__ngram_range: (1, 1)
# 	vect__stop_words: 0

# %%
clf_1.plot_cm([],True)
clf_1.learning_curve([])
# Out:
# Confusion Matrix
# [[ 79   6   5   5   3   4   7  28   7   6   1   8   8  14  15  60  16   6
#    10  31]
#  [  4 156  34  33  14  40  11  20   5   3   5  10  15  10  14   3   2   4
#     3   3]
#  [  3  29 183  36  22  28   7  31   4   5   2   5   6  11   4   2   5   4
#     2   5]
#  [  5  19  49 152  38  15  19  19   7   1   3   7  36   7   3   1   3   2
#     5   1]
#  [  4  17  18  30 165   9  24  37   3   2   4   9  21  16   9   3   8   2
#     1   3]
#  [  2  43  48  21  13 184   5  25   4   3   2   9   8   6  11   1   5   2
#     2   1]
#  [  1  10  10  14  24   3 224  36   6   4   6   1  15   5  16   6   5   1
#     2   1]
#  [  9   3  11   5  11   9  17 221  26   4   5   1  22  10  14   5  10   6
#     5   2]
#  [  5   3   4   4   8   6  15  62 208   9   1   6  13   9  11   3  12   6
#     9   4]
#  [ 10   7   4   3   4   1   4  38  10 201  51   5   9  10   5   5  11   3
#     8   8]
#  [  8   0   4   5   0   1   7  26   6  51 249   2   5   4   7   2   5   6
#     5   6]
#  [  3   6  14  13  13   7   8  39   8   4   2 187  21   8   8   4  20   6
#    21   4]
#  [  3  18  10  20  27  12  20  55  14   8   4  15 117  22  20   2  14   4
#     5   3]
#  [ 10  18   6   6   7  11  11  42  15  10   6   2  18 170  14   4  18   6
#    11  11]
#  [  6  12  12   6   6   5   6  48   7   9   6   7  20   9 199   2  14   3
#     8   9]
#  [ 43   4  10   2   1   6   3  24   3   2   4   5   7   9   9 198  12  10
#    10  36]
#  [  9   6   3   4   1   4   5  38   8  10   7  16  10  20  11  16 141   6
#    32  17]
#  [ 14   4   3   1   0   1   6  26   8   8   5   5   4  12  10  10  19 209
#    26   5]
#  [ 15   1   8   5   3   0   4  21  13   5   5   3   8  20  15  11  64  15
#    78  16]
#  [ 25   3   7   2   2   2   5  28   6   5   2   1   3   6   6  66  22   5
#    14  41]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-66b16a2187ca> in <module>
#       1 clf_1.plot_cm([],True)
#       2 clf_1.learning_curve([])
# ----> 3 clf.eval_best_n_params(0.8)
#       4 sorted(score_dict.keys())
#
# NameError: name 'clf' is not defined

# %%
clf_1.eval_best_n_params(0.8)
sorted(clf_1.score_dict.keys())
# Out:
# Finding most common params for the top 1 values
# [{DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'): 1}, {1: 1}, {20: 1}, {'l2': 1}, {12000: 1}, {(1, 1): 1}, {0: 1}]
# [(0.481616189084152, 2),
#  (0.488246004126663, 1),
#  (0.4896588450735372, 3),
#  (0.49010018937640193, 4)]

# %%
clf_2 = m.Classifier(1,AdaBoostClassifier())

params_trial_2 = {
    'vect__max_features': [(12000,50000)],
    'vect__ngram_range': [(1, 1)],
    'tfidf__norm': [('l2')],
    'vect__stop_words' : [stop_words_no_nums],
    'clf__base_estimator': [DecisionTreeClassifier(criterion='gini',max_depth=1000,min_samples_leaf=1,min_samples_split=0.001,splitter='random',ccp_alpha=0.0001)],
    'clf__n_estimators': [10,20],
    'clf__learning_rate': (1,1.2),
}

clf_2.fit(params_trial_1,5)
clf_2.plot_cm([],True)
clf_2.learning_curve([])
clf_2.eval_best_n_params(0.8)
sorted(clf_2.score_dict.keys())
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  10 out of  20 | elapsed:  3.7min remaining:  3.7min
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:  5.6min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  7.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  7.2min finished
# done in 533.776s
#
# scores!
# mean: 0.480 std: (+/-0.022) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.488 std: (+/-0.012) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.482 std: (+/-0.011) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.493 std: (+/-0.011) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# Best score:
# 0.493 (+/-0.011)
# with parameters set:
# 	clf__base_estimator: DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')
# 	clf__learning_rate: 1
# 	clf__n_estimators: 20
# 	tfidf__norm: 'l2'
# 	vect__max_features: 12000
# 	vect__ngram_range: (1, 1)
# 	vect__stop_words: 0
# Confusion Matrix
# [[ 94   3   6   0   3   3   8  33   8  10   3   4   7  10  15  55   9   8
#    13  27]
#  [  5 171  54  22  15  38   6  16   4   5   0   5  13   5  15   3   2   5
#     3   2]
#  [  3  28 189  37  24  32   5  22   5  10   4   1  10   8   3   1   2   4
#     6   0]
#  [  6  26  41 149  36  18  12  22   1   2   0   6  44   9   7   2   2   2
#     7   0]
#  [  4  13  22  40 176   6  23  36   6   2   4   4  25   8   4   3   2   2
#     4   1]
#  [  2  56  43  21  14 186   3  24   6   2   0   9  11   4   3   2   2   4
#     2   1]
#  [  5  13   9  25  30   6 198  40   9   2   0   0  25   7   7   6   5   1
#     2   0]
#  [ 10   5  11   8  11  10  11 221  31   4   1   2  23   7   7   7   6   7
#    11   3]
#  [  7   6   7   1   7   7   8  58 218   9   4   3  14   6  14   7   6   3
#     8   5]
#  [  5   4   7   9   6   1   5  40   1 210  60   3   6   7   6   3   5   5
#     8   6]
#  [  4   0   8   2   1   1   2  28   7  65 239   0   7   5   3   7   5   1
#     8   6]
#  [  7  15  18   5  11  14   8  35   5   5   2 175  12   4  16   2  31   9
#    15   7]
#  [  4  17  25  24  22  19  10  58  11   7   4  12 125  17  17   2   5   1
#     8   5]
#  [ 18  10  18   4   6   8   6  56  15   7   2   6  21 173   7   8   5   2
#    13  11]
#  [  8   4   8   1   4   6   4  53  10   5   7  12  28  16 190   3  11   2
#    15   7]
#  [ 35   3  10   2   2   2   3  30   4   3   5   3  10   7   5 207   2  14
#    14  37]
#  [ 10   2  10   3   3   4   5  48   8   3   4   5   9  12  12  16 162   7
#    19  22]
#  [ 25   4   2   1   1   4   1  23   3   7   1   5   5   7  14  17  12 212
#    22  10]
#  [ 21   6   7   2   1   3   3  38   9   3   2   5   9  14  10  13  80   8
#    64  12]
#  [ 31   3   6   1   1   0   2  33   2   3   2   3   2   7   5  59  23   9
#    10  49]]
# Finding most common params for the top 1 values
# [{DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'): 1}, {1: 1}, {20: 1}, {'l2': 1}, {12000: 1}, {(1, 1): 1}, {0: 1}]
# [(0.47984838948009595, 1),
#  (0.4817922813976268, 3),
#  (0.48780219836035277, 2),
#  (0.4931057534559143, 4)]

# %%
#0.493 (+/-0.011)
clf_3 = m.Classifier(1,AdaBoostClassifier())

params_trial_3 = {
    'vect__max_features': [(10000,12000,15000)],
    'vect__ngram_range': [(1, 1)],
    'tfidf__norm': [('l2')],
    'vect__stop_words' : [stop_words_no_nums],
    'clf__base_estimator': [DecisionTreeClassifier(criterion='gini',max_depth=1000,min_samples_leaf=1,min_samples_split=0.001,splitter='random',ccp_alpha=0.0001)],
    'clf__n_estimators': [15,20,25],
    'clf__learning_rate': (0.9,1,1.1),
}

clf_3.fit(params_trial_1,5)
clf_3.plot_cm([],True)
clf_3.learning_curve([])
clf_3.eval_best_n_params(0.8)
sorted(clf_3.score_dict.keys())
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  10 out of  20 | elapsed:  6.3min remaining:  6.3min
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed:  8.9min remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 16.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 16.6min finished
# done in 1112.525s
#
# scores!
# mean: 0.485 std: (+/-0.018) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.488 std: (+/-0.019) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.483 std: (+/-0.009) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.492 std: (+/-0.019) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# Best score:
# 0.492 (+/-0.019)
# with parameters set:
# 	clf__base_estimator: DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')
# 	clf__learning_rate: 1
# 	clf__n_estimators: 20
# 	tfidf__norm: 'l2'
# 	vect__max_features: 12000
# 	vect__ngram_range: (1, 1)
# 	vect__stop_words: 0
# Confusion Matrix
# [[ 85   7   3   1   2   3   8  33   7   6   5   8   6  10  11  46  13  13
#    11  41]
#  [  4 160  31  29  13  44  17  20   9   4   5   4  13  11  14   1   4   4
#     2   0]
#  [  0  23 173  36  24  45  13  23   8   6   2   3   5  11   4   0   7   3
#     5   3]
#  [  1  21  38 146  48  20  20  19   6   1   0   4  38  13   7   1   2   1
#     5   1]
#  [  3  16  17  32 183   7  21  31   8   1   1   3  22  12   3   2   4   5
#    12   2]
#  [  3  41  52  14  13 187  10  27   8   1   0   2  11   3   6   3   2   3
#     6   3]
#  [  3  12  10  34  22   5 200  38  10   4   5   2  15   5   9   3   6   0
#     7   0]
#  [  3   6  11   2  16   9  15 221  30   7   5   1  25   7   8   5   9   7
#     7   2]
#  [  3   2   5   3  16   6  13  64 201   7   1   4  14   6  11   4  10  10
#    12   6]
#  [  6  10   6   5   3   5   9  39   5 186  79   4   1   7   5   3   7   5
#     8   4]
#  [  4   2   7   2   4   3   4  29   7  51 243   0   5   9   8   1   6   3
#     6   5]
#  [  6  19  12   9  12  11  10  35   8   4   5 188  14   8   4   1  23   5
#    19   3]
#  [  1  28  20  20  26  31  21  44  16   7   4  15  98  23  12   2   8   3
#     9   5]
#  [ 12  18  13   7  10  17  16  40  15   6   5   2   9 165  12   7  17   5
#    14   6]
#  [  6   9   7   4   7   9  11  43   9   8   8   4  19  20 186   4  13   8
#    15   4]
#  [ 30   3   6   1   4   3   5  28   2   3   2   2   5  12   8 197   5  10
#    18  54]
#  [  6   1   7   2   4   9   8  37  10   4   5  11  12  11   6  11 160   9
#    38  13]
#  [ 22   2   3   0   2   2   3  20   4   8   5   7   4  13  12  10  16 209
#    22  12]
#  [ 18   5   8   6   5   3   4  28   5   2   6   8   6  22  11  11  68  15
#    67  12]
#  [ 27   0   2   1   2   1   4  31   3   2   2   4   5   9  10  58  25   9
#    15  41]]
# Finding most common params for the top 1 values
# [{DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'): 1}, {1: 1}, {20: 1}, {'l2': 1}, {12000: 1}, {(1, 1): 1}, {0: 1}]
# [(0.4832952197207764, 3),
#  (0.4849733517278888, 1),
#  (0.48762630140111973, 2),
#  (0.49151514014908654, 4)]

# %%
# we see taht the same selections were made again for the params and so we will find test scores
clf_2.eval_on_test([],True)
# Out:
# Evaluation on test set:
#
# Accuracy Score : 0.45246946362187995
# Precision Score : 0.45246946362187995
# Recall Score : 0.45246946362187995
# F1 Score : 0.45246946362187995
# Confusion Matrix
# [[ 94   3   6   0   3   3   8  33   8  10   3   4   7  10  15  55   9   8
#    13  27]
#  [  5 171  54  22  15  38   6  16   4   5   0   5  13   5  15   3   2   5
#     3   2]
#  [  3  28 189  37  24  32   5  22   5  10   4   1  10   8   3   1   2   4
#     6   0]
#  [  6  26  41 149  36  18  12  22   1   2   0   6  44   9   7   2   2   2
#     7   0]
#  [  4  13  22  40 176   6  23  36   6   2   4   4  25   8   4   3   2   2
#     4   1]
#  [  2  56  43  21  14 186   3  24   6   2   0   9  11   4   3   2   2   4
#     2   1]
#  [  5  13   9  25  30   6 198  40   9   2   0   0  25   7   7   6   5   1
#     2   0]
#  [ 10   5  11   8  11  10  11 221  31   4   1   2  23   7   7   7   6   7
#    11   3]
#  [  7   6   7   1   7   7   8  58 218   9   4   3  14   6  14   7   6   3
#     8   5]
#  [  5   4   7   9   6   1   5  40   1 210  60   3   6   7   6   3   5   5
#     8   6]
#  [  4   0   8   2   1   1   2  28   7  65 239   0   7   5   3   7   5   1
#     8   6]
#  [  7  15  18   5  11  14   8  35   5   5   2 175  12   4  16   2  31   9
#    15   7]
#  [  4  17  25  24  22  19  10  58  11   7   4  12 125  17  17   2   5   1
#     8   5]
#  [ 18  10  18   4   6   8   6  56  15   7   2   6  21 173   7   8   5   2
#    13  11]
#  [  8   4   8   1   4   6   4  53  10   5   7  12  28  16 190   3  11   2
#    15   7]
#  [ 35   3  10   2   2   2   3  30   4   3   5   3  10   7   5 207   2  14
#    14  37]
#  [ 10   2  10   3   3   4   5  48   8   3   4   5   9  12  12  16 162   7
#    19  22]
#  [ 25   4   2   1   1   4   1  23   3   7   1   5   5   7  14  17  12 212
#    22  10]
#  [ 21   6   7   2   1   3   3  38   9   3   2   5   9  14  10  13  80   8
#    64  12]
#  [ 31   3   6   1   1   0   2  33   2   3   2   3   2   7   5  59  23   9
#    10  49]]
