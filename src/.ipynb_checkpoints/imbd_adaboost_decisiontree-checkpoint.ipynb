# %%
import model as m
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
#stop word sets specified for this data set
path = "../data/stop_words_imbd/"
with open(path+"stop_words_no_nums.txt", 'r') as content_file:
        content = content_file.read().replace(" ","").replace("\n","").split(",")
        stop_words_no_nums = frozenset(content)
with open(path+"stop_words_with_nums.txt", 'r') as content_file:
        content = content_file.read().replace(" ","").replace("\n","").split(",")
        stop_words_with_nums = frozenset(content)

# %%
clf_1 = m.Classifier(0,AdaBoostClassifier())

params_trial_1 = {
    'vect__max_features': [(12000)],
    'vect__ngram_range': [(1, 1)],
    'tfidf__norm': [('l2')],
    'vect__stop_words' : [stop_words_no_nums],
    'clf__base_estimator': [DecisionTreeClassifier(criterion='gini',max_depth=1000,min_samples_leaf=1,min_samples_split=0.001,splitter='random',ccp_alpha=0.0001)],
    'clf__n_estimators': [10,20],
    'clf__learning_rate': (0.8,1),
}

clf_1.fit(params_trial_1,5)
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done  10 out of  20 | elapsed: 22.6min remaining: 22.6min
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed: 29.1min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 34.6min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 34.6min finished
# done in 2785.844s
#
# scores!
# mean: 0.732 std: (+/-0.009) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.771 std: (+/-0.008) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.731 std: (+/-0.009) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.774 std: (+/-0.009) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# Best score:
# 0.774 (+/-0.009)
# with parameters set:
# 	clf__base_estimator: DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')
# 	clf__learning_rate: 1
# 	clf__n_estimators: 20
# 	tfidf__norm: 'l2'
# 	vect__max_features: 12000
# 	vect__ngram_range: (1, 1)
# 	vect__stop_words: 0

# %%
clf_1.plot_cm([],True)
clf_1.learning_curve([])
clf_1.eval_best_n_params(0.8)
sorted(score_dict.keys())
# Out:
# Confusion Matrix
# [[9826 2675]
#  [2940 9559]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-66b16a2187ca> in <module>
#       1 clf_1.plot_cm([],True)
#       2 clf_1.learning_curve([])
# ----> 3 clf.eval_best_n_params(0.8)
#       4 sorted(score_dict.keys())
#
# NameError: name 'clf' is not defined

# %%
clf_1.eval_best_n_params(0.8)
sorted(clf_1.score_dict.keys())
# Out:
# Finding most common params for the top 1 values
# [{DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'): 1}, {1: 1}, {20: 1}, {'l2': 1}, {12000: 1}, {(1, 1): 1}, {0: 1}]
# [(0.7310800000000001, 3), (0.7324400000000001, 1), (0.77148, 2), (0.7744, 4)]

# %%
clf_2 = m.Classifier(0,AdaBoostClassifier())

params_trial_2 = {
    'vect__max_features': [(10000,12000,15000)],
    'vect__ngram_range': [(1, 1)],
    'tfidf__norm': [('l2')],
    'vect__stop_words' : [stop_words_no_nums],
    'clf__base_estimator': [DecisionTreeClassifier(criterion='gini',max_depth=1000,min_samples_leaf=1,min_samples_split=0.001,splitter='random',ccp_alpha=0.0001)],
    'clf__n_estimators': [15,20,25],
    'clf__learning_rate': (0.8,1,1.2),
}

clf_2.fit(params_trial_1,5)
clf_2.plot_cm([],True)
clf_2.learning_curve([])
clf_2.eval_best_n_params(0.8)
sorted(clf_2.score_dict.keys())
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  10 out of  20 | elapsed:  9.6min remaining:  9.6min
# [Parallel(n_jobs=-1)]: Done  15 out of  20 | elapsed: 49.9min remaining: 16.6min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 55.4min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed: 55.4min finished
# done in 3781.949s
#
# scores!
# mean: 0.733 std: (+/-0.007) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.773 std: (+/-0.003) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 0.8, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.739 std: (+/-0.011) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 10, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# mean: 0.770 std: (+/-0.008) for {'clf__base_estimator': DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'), 'clf__learning_rate': 1, 'clf__n_estimators': 20, 'tfidf__norm': 'l2', 'vect__max_features': 12000, 'vect__ngram_range': (1, 1), 'vect__stop_words': 0}
# Best score:
# 0.773 (+/-0.008)
# with parameters set:
# 	clf__base_estimator: DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random')
# 	clf__learning_rate: 0.8
# 	clf__n_estimators: 20
# 	tfidf__norm: 'l2'
# 	vect__max_features: 12000
# 	vect__ngram_range: (1, 1)
# 	vect__stop_words: 0
# Confusion Matrix
# [[9723 2778]
#  [2993 9506]]
# Finding most common params for the top 1 values
# [{DecisionTreeClassifier(ccp_alpha=0.0001, class_weight=None, criterion='gini',
#                        max_depth=1000, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=0.001,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='random'): 1}, {0.8: 1}, {20: 1}, {'l2': 1}, {12000: 1}, {(1, 1): 1}, {0: 1}]
# [(0.73328, 1), (0.73856, 3), (0.7696799999999999, 4), (0.7727999999999999, 2)]

# %%
# we see taht the same selections were made again for the params and so we will find test scores
clf_2.eval_on_test([],True)
# Out:
# Evaluation on test set:
#
# Accuracy Score : 0.76916
# Precision Score : 0.76916
# Recall Score : 0.76916
# F1 Score : 0.76916
# Confusion Matrix
# [[9723 2778]
#  [2993 9506]]
