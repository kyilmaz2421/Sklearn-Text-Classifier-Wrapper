# %%
import pandas as pd
train = pd.read_csv("../data/imbd/train.txt",header=None)
test = pd.read_csv("../data/imbd/test.txt",header=None)
test[1]
# Out:
# 0          9
# 1          9
# 2          9
# 3         10
# 4         10
#         ...
# 24995      1
# 24996      1
# 24997      1
# 24998      3
# 24999      1
# Name: 1, Length: 25000, dtype: object

# %%
from pprint import pprint
from time import time
import logging
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,confusion_matrix

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

print(__doc__)

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')


# #############################################################################
# Load some categories from the training set
#categories = [
    #'alt.atheism',
    #'talk.religion.misc',
#]
# Uncomment the following to do the analysis on all the categories
#categories = None

#print("Loading 20 newsgroups dataset for categories:")
#print(categories)

#print("%d documents" % len(data.filenames))
#print("%d categories" % len(data.target_names))
#print()

# #############################################################################
# Define a pipeline combining a text feature extractor with a simple
# classifier
pipeline = Pipeline(steps = [
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LogisticRegression()),
])

# uncommenting more parameters will give better exploring power but will
# increase processing time in a combinatorial way
parameters = {
    'vect__min_df': ([0]),
    #'vect__max_features': (None, 5000, 10000, 100000),
    #'vect__ngram_range': ((1, 1)),  # unigrams or bigrams
    'tfidf__use_idf': ([False]),
    # 'tfidf__norm': ('l1', 'l2'),
    #'clf__C': ([0.01,0.1]),
    #'clf__penalty': ('l2', 'l1'),
     'clf__max_iter': (1,2),
}

if __name__ == "__main__":
    # multiprocessing requires the fork to happen in a __main__ protected
    # block

    # find the best parameters for both the feature extraction and the
    # classifier
    grid_search = GridSearchCV(pipeline, parameters,cv=2, n_jobs=-1, verbose=5, refit = True,return_train_score = True)

    print("Performing grid search...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameter set:")
    pprint(parameters)
    t0 = time()
    grid_search.fit(train[0], train[1])
    print("done in %0.3fs" % (time() - t0))
    print()
    
    print("scores!")
    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
        
    print("Best score:")
    print("%0.3f (+/-%0.03f)" % (grid_search.best_score_, std * 2))
    print("with parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
    print(grid_search)
# Out:
# Automatically created module for IPython interactive environment
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameter set:
# {'clf__max_iter': (1, 2), 'tfidf__use_idf': [False], 'vect__min_df': [0]}
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   4 | elapsed:    9.1s remaining:    9.1s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    9.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    9.3s finished
# /Users/kaan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/kaan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# done in 14.012s
#
# scores!
# 0.204 (+/-0.000) for {'clf__max_iter': 1, 'tfidf__use_idf': False, 'vect__min_df': 0}
# 0.278 (+/-0.010) for {'clf__max_iter': 2, 'tfidf__use_idf': False, 'vect__min_df': 0}
# Best score:
# 0.278 (+/-0.010)
# with parameters set:
# 	clf__max_iter: 2
# 	tfidf__use_idf: False
# 	vect__min_df: 0
# GridSearchCV(cv=2, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vect',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accents=None,
#                                                         tok...
#                                                            intercept_scaling=1,
#                                                            l1_ratio=None,
#                                                            max_iter=100,
#                                                            multi_class='warn',
#                                                            n_jobs=None,
#                                                            penalty='l2',
#                                                            random_state=None,
#                                                            solver='warn',
#                                                            tol=0.0001,
#                                                            verbose=0,
#                                                            warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'clf__max_iter': (1, 2), 'tfidf__use_idf': [False],
#                          'vect__min_df': [0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=5)
# /Users/kaan/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
import matplotlib.pyplot as plt
import numpy as np
#import itertools
#from sklearn.metrics import plot_confusion_matrix

y_pred = int(grid_search.predict(test[0]))
y_test = int(test[1])
print(y_pred)
print(len(y_pred))
print(y_test)
print(len(y_test))

countI = 0
countS = 0
for item in y_pred:
    if type(item)== int:
        print("int: "+str(item))
        countI+=1
    elif type(item)!= int:
        countS+=1
        print("str: "+str(item))
        
print(countI)
print(countS)

print(countI+countS)

cnf_matrix = confusion_matrix(y_test,y_pred)
print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred)))
print('Precision Score : ' + str(precision_score(y_test,y_pred,average='micro')))
print('Recall Score : ' + str(recall_score(y_test,y_pred,average='micro')))
print('F1 Score : ' + str(f1_score(y_test,y_pred,average='micro')))
print('Confusion Matrix : \n' + str(cnf_matrix))
class_names = test.target_names
# Out:
# [ 1  1  1 ...  1 10  1]
# 25000
# 0          9
# 1          9
# 2          9
# 3         10
# 4         10
#         ...
# 24995      1
# 24996      1
# 24997      1
# 24998      3
# 24999      1
# Name: 1, Length: 25000, dtype: object
# 25000
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# ...
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 10
# str: 10
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 1
# str: 10
# str: 1
# 0
# 25000
# 25000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e3015d4706c7> in <module>
#      26 print(countI+countS)
#      27
# ---> 28 cnf_matrix = confusion_matrix(y_test,y_pred)
#      29 print('Accuracy Score : ' + str(accuracy_score(y_test,y_pred)))
#      30 print('Precision Score : ' + str(precision_score(y_test,y_pred,average='micro')))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     256
#     257     if labels is None:
# --> 258         labels = unique_labels(y_true, y_pred)
#     259     else:
#     260         labels = np.asarray(labels)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      98     # Check that we don't mix string type with number type
#      99     if (len(set(isinstance(label, str) for label in ys_labels)) > 1):
# --> 100         raise ValueError("Mix of label input types (string and number)")
#     101
#     102     return np.array(sorted(ys_labels))
#
# ValueError: Mix of label input types (string and number)

# %%
def pre_process(self,stop_words,min_df,max_features,ngram_upper_bound):
        train_size = len(self.train["text"])
        test_size = len(self.test["text"])
        vertical_stack = pd.concat([self.train, self.test], axis=0)
        tfidf_transformer = TfidfTransformer()
        if max_features > 0:
            vectorizer = CountVectorizer(ngram_range=(1, ngram_upper_bound),min_df = min_df, max_features= max_features,stop_words=stop_words)
        else:
            vectorizer = CountVectorizer(ngram_range=(1, ngram_upper_bound),min_df = min_df,stop_words=stop_words)
        
        formated_data = vectorizer.fit_transform(vertical_stack["text"])
        formated_data = tfidf_transformer.fit_transform(formated_data).toarray()
        self.X_train = formated_data[0:train_size][:]
        self.X_test = formated_data[train_size:][:]

# %%
import model
from sklearn.svm import LinearSVC
c = model.Classifier(0,LinearSVC())
param = {
            'vect__min_df': ([0]),
            'tfidf__use_idf': ([False]),
        }
        # additionally by the default settings
        # max_feature = None
        # ngram_range = (1,1)
        # max_df=1.0
        # lowercase=True
        # default C
c.fit(param,5)
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__use_idf': [False], 'vect__min_df': [0]}
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   17.0s remaining:   25.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   17.3s finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-30a36aae2b65> in <module>
#      12         # lowercase=True
#      13         # default C
# ---> 14 c.fit(param,5)
#
# ~/Desktop/school/comp551/A2/COMP551miniproject2/src/model.py in fit(self, parameters, cv)
#      96         pprint(parameters)
#      97         t0 = time()
# ---> 98         grid_search.fit(self.X_train, self.Y_train)
#      99         print("done in %0.3fs" % (time() - t0))
#     100         print()
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     713             refit_start_time = time.time()
#     714             if y is not None:
# --> 715                 self.best_estimator_.fit(X, y, **fit_params)
#     716             else:
#     717                 self.best_estimator_.fit(X, **fit_params)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# ~/anaconda3/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1056
#    1057         vocabulary, X = self._count_vocab(raw_documents,
# -> 1058                                           self.fixed_vocabulary_)
#    1059
#    1060         if self.binary:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     968         for doc in raw_documents:
#     969             feature_counter = {}
# --> 970             for feature in analyze(doc):
#     971                 try:
#     972                     feature_idx = vocabulary[feature]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     350                                                tokenize)
#     351             return lambda doc: self._word_ngrams(
# --> 352                 tokenize(preprocess(self.decode(doc))), stop_words)
#     353
#     354         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     263             return self.tokenizer
#     264         token_pattern = re.compile(self.token_pattern)
# --> 265         return lambda doc: token_pattern.findall(doc)
#     266
#     267     def get_stop_words(self):
#
# KeyboardInterrupt:

# %%
c.eval_on_test()

# %%
from sklearn.tree import DecisionTreeClassifier
ccc = model.Classifier(1,DecisionTreeClassifier())

# %%
from sklearn.ensemble import RandomForestClassifier
c3 = model.Classifier(1,RandomForestClassifier())
c3.baseline_fit()
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__use_idf': [False], 'vect__min_df': [0]}
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   12.4s remaining:   18.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   12.6s finished
# /Users/kaan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# done in 19.680s
#
# scores!
# 0.657 (+/-0.032) for {'tfidf__use_idf': False, 'vect__min_df': 0}
# Best score:
# 0.657 (+/-0.032)
# with parameters set:
# 	tfidf__use_idf: False
# 	vect__min_df: 0
#
# Evaluation on test set:
#
# Accuracy Score : 0.5594795539033457
# Precision Score : 0.5594795539033457
# Recall Score : 0.5594795539033457
# F1 Score : 0.5594795539033457
# Confusion Matrix :
# [[194   7   3   4  10   2   1   3   1   4   5   3   1   5   5  47   7   4
#     2  11]
#  [  4 201  33  18  27  39  12   5   5   6   2   2  15   2   9   3   0   3
#     3   0]
#  [  6  59 198  45  17  20   8   5   4   5   0   5   7   1   8   1   2   1
#     2   0]
#  [  3  48  64 172  32  15  10   6   3   0   2   2  19   4   4   3   2   0
#     3   0]
#  [  5  38  31  49 182  11  23   8   3   6   4   4  12   2   1   3   1   0
#     2   0]
#  [  5  69  59  21  16 184   3   4   7   4   2   2   8   4   4   0   1   0
#     1   1]
#  [  4  18  14  18  17   7 287   9   1   1   2   1   4   3   2   0   2   0
#     0   0]
#  [ 10  18  20  16  15   9  31 209  23   7   2   1  11   9   5   4   5   1
#     0   0]
#  [  7  15  10   8   4   1  13  31 287   1   4   1   7   3   2   1   2   0
#     0   1]
#  [  4  12   4   7  10   9   7  13   3 270  31   0   6  12   1   4   3   1
#     0   0]
#  [  2   5   3   4   6   4   6   4   4  34 316   0   2   2   4   1   1   0
#     1   0]
#  [  3  18  10   4  10   9   7   2   4   6   2 297   3   5   4   3   5   0
#     4   0]
#  [ 12  45  31  36  33  14  14  21  17  18  10  13 102   8   9   4   3   1
#     1   1]
#  [ 17  41  17  14  10  12  26  23   5  13  11   4  18 147  10   8   4   7
#     6   3]
#  [  9  11   8   8  10   5   8  13   4  13   4   9  11  16 250   6   6   0
#     2   1]
#  [ 30  11   8   2   5   3   3   7   1   6   1   1   2   9   3 292   4   2
#     2   6]
#  [  9  13   6   4   5   3   8  17   8  15   4  24   2   4   6   9 210   3
#     9   5]
#  [ 19   4   3   4   7   3   3   6   3   5   7   6   3   6   7  14  17 253
#     1   5]
#  [ 11  11   5   4   6   6   2  14   5   7   6   8   4  18   4   9  71   6
#   107   6]
#  [ 49   4   2   3   4   6   0   6   6   5   5   4   5   6   6  61  15   1
#     7  56]]

# %%
import model
from sklearn.ensemble import AdaBoostClassifier
c4 = model.Classifier(0,AdaBoostClassifier())
c4.baseline_fit()
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__use_idf': [False], 'vect__min_df': [0]}
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   35.3s remaining:   53.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   35.7s finished
# done in 60.763s
#
# scores!
# 0.353 (+/-0.010) for {'tfidf__use_idf': False, 'vect__min_df': 0}
# Best score:
# 0.353 (+/-0.010)
# with parameters set:
# 	tfidf__use_idf: False
# 	vect__min_df: 0
#
# Evaluation on test set:
#
# Accuracy Score : 0.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-cb655cd5a704> in <module>
#       2 from sklearn.ensemble import AdaBoostClassifier
#       3 c4 = model.Classifier(0,AdaBoostClassifier())
# ----> 4 c4.baseline_fit()
#
# ~/Desktop/school/comp551/A2/COMP551miniproject2/src/model.py in baseline_fit(self)
#     128         # default C
#     129         self.fit(param,5)
# --> 130         self.eval_on_test()
#     131
#     132
#
# ~/Desktop/school/comp551/A2/COMP551miniproject2/src/model.py in eval_on_test(self)
#     138         #cnf_matrix = confusion_matrix(y_test,y_pred)
#     139         print('Accuracy Score : ' + str(accuracy_score(self.Y_test,res)))
# --> 140         print('Precision Score : ' + str(precision_score(self.Y_test,res, average='micro')))
#     141         print('Recall Score : ' + str(recall_score(self.Y_test,res, average='micro')))
#     142         print('F1 Score : ' + str(f1_score(self.Y_test,res, average='micro')))
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight)
#    1567                                                  average=average,
#    1568                                                  warn_for=('precision',),
# -> 1569                                                  sample_weight=sample_weight)
#    1570     return p
#    1571
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight)
#    1413         raise ValueError("beta should be >0 in the F-beta score")
#    1414     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1415                                     pos_label)
#    1416
#    1417     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1238
#    1239     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# -> 1240     present_labels = unique_labels(y_true, y_pred)
#    1241     if average == 'binary':
#    1242         if y_type == 'binary':
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#      98     # Check that we don't mix string type with number type
#      99     if (len(set(isinstance(label, str) for label in ys_labels)) > 1):
# --> 100         raise ValueError("Mix of label input types (string and number)")
#     101
#     102     return np.array(sorted(ys_labels))
#
# ValueError: Mix of label input types (string and number)

# %%
from sklearn.tree import DecisionTreeClassifier
ccc = model.Classifier(1,DecisionTreeClassifier())
ccc.baseline_fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f83339f085eb> in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
# ----> 2 ccc = model.Classifier(1,DecisionTreeClassifier())
#       3 ccc.baseline_fit()
#
# NameError: name 'model' is not defined
